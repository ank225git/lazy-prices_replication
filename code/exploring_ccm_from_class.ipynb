# %% [markdown]
# Need to create a permno-cik map. Attempting to extract from class ccm dataset

# %%
import pandas as pd
import zipfile
import os

# %%
import pandas as pd

path_2019 = "../data/supplement/ccm_from_class/2019_ccm_cleaned.dta"

df_2019 = pd.read_stata(path_2019)

print(df_2019.shape)
df_2019
# Out:
# (3552, 39)
#    gvkey  lpermno   datadate   fyear   tic     sic   sic3            td  \
# 0   1004  54594.0 2019-05-31  2018.0   AIR  5080.0  508.0    141.699997
# 1   1045  21020.0 2019-12-31  2019.0   AAL  4512.0  451.0  33444.000000
# 2   1050  11499.0 2019-12-31  2019.0  CECE  3564.0  356.0     87.083000
# 3   1072  81912.0 2019-03-31  2018.0   AVX  3670.0  367.0      0.000000
# 4   1076  10517.0 2019-12-31  2019.0   PRG  7359.0  735.0    710.416016
#
#    long_debt_dum            me  ...        mb    prof_a     ppe_a    cash_a  \
# 0            1.0   1046.770874  ...  1.092849  0.101173  0.229897  0.027089
# 1            1.0  12280.862305  ...  1.206665  0.100408  0.728927  0.066406
# 2            1.0    269.149414  ...  1.186308  0.073980  0.070676  0.090442
# 3            0.0   2927.442871  ...  1.193107  0.143644  0.162002  0.289061
# 4            1.0   3810.264893  ...  1.628603  0.341853  0.602309  0.017513
#
# ...

# %% [markdown]
# -> for some reason few permno (3552)

# %%
path_class = "../data/supplement/ccm_from_class/CCM_cleaned_for_class.dta"

df_class = pd.read_stata(path_class)

print(df_class.shape)
df_class
# Out:
# (223001, 43)
#    gvkey   fyear   datadate  lpermno gsector     sic   sic3  age    tic state  \
# 0   1000  1975.0 1975-12-31  25881.0          3089.0  308.0  0.0   AE.2
# 1   1000  1976.0 1976-12-31  25881.0          3089.0  308.0  1.0   AE.2
# 2   1000  1977.0 1977-12-31  25881.0          3089.0  308.0  2.0   AE.2
# 3   1001  1983.0 1983-12-31  10015.0      25  5812.0  581.0  0.0  AMFD.    OK
# 4   1001  1984.0 1984-12-31  10015.0      25  5812.0  581.0  1.0  AMFD.    OK
#
#    ...  tnic3hhi  tnic3tsimm  prodmktfluid  delaycon  equitydelaycon  \
# 0  ...       NaN         NaN           NaN       NaN             NaN
# 1  ...       NaN         NaN           NaN       NaN             NaN
# 2  ...       NaN         NaN           NaN       NaN             NaN
# 3  ...       NaN         NaN           NaN       NaN             NaN
# 4  ...       NaN         NaN           NaN       NaN             NaN
#
#    debtdelaycon  privdelaycon     l_emp   l_ppent  l_laborratio
# ...

# %% [markdown]
# -> this is probably it, 22550 distinct lpermno
#
# some descriptions:
# lpermno,CRSP Identifier,,,,,,,
# sic,Industry (4 digit),,,,,,,
# sic3,Industry (3 digit),,,,,,,
